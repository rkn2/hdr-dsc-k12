# %% [markdown]
# **Chapter 11 - Understanding Randomness**
#
# <img src="media_chapter_10/media/image2.png" style="width:7.5in;height:2.34722in" />

# %% [markdown]
# **<u>Randomness:</u>**
#
# - Statisticians don’t think of randomness as the annoying tendency of things to be unpredictable or haphazard.
#
# - Statisticians use randomness as a tool.

# %% [markdown]
# **<u>Simulation:</u>**
#
# - We need an imitation of a real process so we can manipulate and control it. In short, we are going to simulate reality.
#
# - The sequence of events we want to investigate is called a **trial.**
#
# - The basic building block of a simulation is called a **component**.
#
#   - Trials usually involve several components.
#
# - After the trial, we record what happened—our response variable.

# %% [markdown]
# **<u>Seven Steps to a Simulation:</u>**

# %% [markdown]
# **Specify how to model a component outcome using equally likely random digits:**
#
# 1.  Identify the component to be repeated.
#
# 2.  Explain how you will model the component’s outcome.

# %% [markdown]
# **Specify how to simulate trials:**
#
# 3.  Explain how you will combine the components to model a trial.
#
# 4.  State clearly what the response variable is.

# %% [markdown]
# **Put it all together to run the simulation:**
#
# 5.  Run several trials.

# %% [markdown]
# **Analyze the response variable:**
#
# 6.  Collect and summarize the results of all the trials.
#
# 7.  State your conclusion.

# %% [markdown]
# **Cereal Example:**
#
# Suppose a cereal manufacturer puts pictures of famous athletes on cards in boxes of cereal in the hope of boosting sales. The manufacturer announces that 20% of the boxes contain a picture of champion gymnast Simone Biles, 30% a picture of basketball star Caitlin Clark, and the rest a picture of tennis pro Serena Williams. You want all three pictures. How many boxes of cereal do you expect to have to buy in order to get the complete set?

# %% [markdown]
# **Specify how to model a component outcome using equally likely random digits:**
#
# 1\. Identify the component to be repeated.
#
# > In this case, our component is the opening of a box of cereal.
#
# 2\. Explain how you will model the component’s outcome.
#
# > The digits from 0 to 9 are equally likely to occur. Because 20% of the boxes contain Simone’s picture, we’ll use 2 of the 10 digits to represent that outcome. Three of the 10 digits can model the 30% of boxes with Caitlin’s cards, and the remaining 5 digits can represent the 50% of boxes with Serena.
# >
# > One possible assignment of the digits, then, is
# >
# > **0, 1 Simone 2, 3, 4 Caitlin 5, 6, 7, 8, 9 Serena.**

# %% [markdown]
# **Specify how to simulate trials:**
#
# 3\. Explain how you will combine the components to model a trial.
#
# > We pretend to open boxes (repeat components) until our collection is complete. We do this by looking at each random digit and indicating what picture it represents. We continue until we’ve found all three.
#
# 4\. State clearly what the response variable is.
#
# > What are we interested in? We want to ﬁnd out the number of boxes it might take to get all three pictures.

# %% [markdown]
# **Put it all together to run the simulation:**
#
# 5\. Run several trials.
#
# 89064\| 2730\|8 64568 1\|4121 98226 65388 58732 85801 69902 78431 10380 42006 76641
#
# Keep track of what happens:
#
# | **Trial Number** | **Component Outcomes** | **Trial Outcomes: y = Number of Boxes** |
# |----|----|----|
# | 1 | **8**9**0**6**4 = Serena**, Serena, **Simone**, Serena, **Caitlin** | 5 |
# | 2 | **27**3**0** = **Caitlin**, **Serena**, Caitlin, **Simone** | 4 |
# | 3 | 8 64568 1 | 7 |
# | 4 |  |  |
# | 5 |  |  |
# | 6 |  |  |
# | 7 |  |  |
# | 8 |  |  |
# | 9 |  |  |
# | 10 |  |  |

# %% [markdown]
# **Analyze the response variable:**
#
# 6\. Collect and summarize the results of all the trials.
#
# 7\. State your conclusion, as always, in the context of the question you wanted to answer.

# %% [markdown]
# **Example 1:**
#
# Suppose the Philadelphia Phillies are playing the Boston Red Sox in the best of seven World Series. The first two are played at one team’s home ballpark (Philadelphia), the next three at the other team’s park (Boston), and the final two (if needed) are played back in Philadelphia. The first team to win four games is the World Series Champion. Records over the past century show that there is a home field advantage; in any game the home team has about a 55% chance of winning. <img src="media_chapter_10/media/image1.png" style="width:2.54688in;height:1.33711in" />
#
# <u>Questions:</u>
#
# Does the current system of alternating ballparks even out the home field advantage? How often will Philadelphia, who begins at home, win the series?
#
# <u>Set up the simulation:</u>
#
# Components:
#
# Outcomes:
#
# Trial:
#
# Response variable:
#
# Mechanics:
#
# 89059 43528 10547 40115 82234 86902 04121 83889 76208 31076
#
# 87736 04666 75145 49175 76754 07884 92564 80793 22573 67902
#
# 76488 88899 15860 07370 13431 84041 69202 18912 83173 11983
#
# Analyze:
#
# Conclusion:

# %% [markdown]
# **Example 2:**
#
# Fifty-seven students participated in a lottery for a particularly desirable dorm room—a triple with a fireplace and private bath in the tower. Twenty of the participants were members of the same varsity team. When all three winners were members of the team, the other students cried foul. Could an all-team outcome reasonably be expected to happen if everyone had a fair shot at the room?
#
# Run a simulation of six (6) trials and interpret your results.
#
# 74029 43902 77551 86333 25054 58891 56390 90765 39459 54398 95116 87712 17261 98993 77272 35237 16508 34474 17468 50940 30114 88341

# %% [markdown]
# **Example 3:**
#
# At the start of the season, Sean was an 80% free throw shooter. Conduct six (6) trials of a simulation to determine how many shots in a row he would typically make before he misses.
#
# 73184 95907 05179 51002 83374 52297 07769 99792 78365 93487
#
# As the season has progressed, his free throw percentage has increased from 80% to 86%. Conduct six (6) trials of a simulation to determine how many shots in a row he would typically make before he misses.
#
# 37542 04805 64894 74296 24805 24037 20636 10402 00822 08422 68953 19645 09303 23209 02560 15953 34764 35080 99019 02529 09376 70715 38311 31165 88676 74397 04436 12807 99970 80157 36147 64032 36653
#
# Still shooting 86%, how many shots may he make from the free throw line if he is given 5 attempts in a game? Run five (5) trials.
#
# 37542 04805 64894 74296 24805 24037 20636 10402 00822 08422 68953 19645 09303 23209 02560 15953 34764 35080 99019 02529 09376 70715
#
# Still an 86% free throw shooter, we want to know how likely it will be that Sean hits both attempts at the free throw line when he is fouled. Run ten (10) trials.
#
# 37542 04805 64894 74296 24805 24037 20636 10402 00822 08422 68953 19645 09303 23209 02560 15953 34764 35080 99019 02529 09376 70715
#
# What if Sean is fouled and earns a 1-and-1 situation? How many points do we expect him to earn, on average? Run ten (10) trials.
#
# 38311 31165 88676 74397 04436 12807 99970 80157 36147 64032 36653 98951 16877 12171 83374 73184 77551 95116 31076 82234 00152 09443
